# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm as cm
import numpy as np
from sklearn.naive_bayes import GaussianNB
# %matplotlib inline

# %%
train=pd.read_csv('../input/train.csv')
train.describe()
# Out:
#              row_id             x             y      accuracy          time  \
# count  2.911802e+07  2.911802e+07  2.911802e+07  2.911802e+07  2.911802e+07
# mean   1.455901e+07  4.999770e+00  5.001814e+00  8.284912e+01  4.170104e+05
# std    8.405649e+06  2.857601e+00  2.887505e+00  1.147518e+02  2.311761e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    7.279505e+06  2.534700e+00  2.496700e+00  2.700000e+01  2.030570e+05
# 50%    1.455901e+07  5.009100e+00  4.988300e+00  6.200000e+01  4.339220e+05
# 75%    2.183852e+07  7.461400e+00  7.510300e+00  7.500000e+01  6.204910e+05
# max    2.911802e+07  1.000000e+01  1.000000e+01  1.033000e+03  7.862390e+05
#
#            place_id
# count  2.911802e+07
# mean   5.493787e+09
# std    2.611088e+09
# min    1.000016e+09
# 25%    3.222911e+09
# 50%    5.518573e+09
# 75%    7.764307e+09
# max    9.999932e+09

# %%
places=train['time'].unique()

# %%
testTrain=train[:1000]
testTrain.head()
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713
# 2       2  8.3078  7.0407        74  322648  1137537235
# 3       3  7.3665  2.5165        65  704587  6567393236
# 4       4  4.0961  1.1307        31  472130  7440663949

# %%
testTrain[testTrain['place_id']==1012925232]
# Out:
#      row_id       x       y  accuracy    time    place_id
# 268     268  8.6562  7.2322        65  476607  1012925232

# %%
g=testTrain.groupby('place_id')
summary=pd.DataFrame()
summary['yMin']=g['y'].min()
summary
# Out:
#               yMin
# place_id
# 1012925232  7.2322
# 1022464600  5.6343
# 1023416297  4.3253
# 1042808747  4.0328
# 1049291060  0.3452
# 1050459890  7.3629
# 1054262967  1.3583
# 1054527412  8.3914
# 1060030987  5.1332
# 1066682022  3.0801
# 1068923678  4.8482
# 1086228700  9.7149
# 1086660186  0.2284
# 1092851964  2.2669
# 1099456046  3.1496
# 1104210907  3.1980
# 1117174075  9.5440
# 1137537235  7.0407
# 1151461640  2.6458
# 1167283530  1.9918
# 1170828129  0.1269
# 1176283186  0.3945
# 1213329203  4.1475
# 1217568844  0.0338
# 1231289461  8.7866
# 1235005668  3.5984
# 1243899834  3.4452
# 1253803156  0.0758
# 1259749250  4.5146
# 1269500921  4.6408
# ...            ...
# 9768707769  6.5322
# 9769096481  9.3697
# 9781042850  2.8166
# 9784464752  1.2462
# 9800698374  8.2309
# 9818046522  1.1385
# 9827652585  7.0919
# 9841775341  1.4831
# 9849435615  9.5578
# 9852078378  3.1865
# 9855020231  9.9630
# 9861172599  9.1361
# 9864618995  9.9257
# 9866083589  1.3338
# 9869878827  7.8649
# 9874278512  6.2225
# 9883722775  2.4060
# 9885174082  7.5588
# 9891754890  8.8177
# 9895452541  2.0175
# 9896320437  0.3006
# 9898992724  8.6845
# 9908763896  8.0681
# 9931249544  4.3720
# 9937870870  2.7520
# 9938828781  8.8671
# 9962169160  3.0450
# 9970375384  2.7337
# 9973067176  0.0421
# 9986262808  9.4131
#
# [993 rows x 1 columns]

# %%
# gnb=GaussianNB()
# gnb.fit(train[['x','y','time']], train['place_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-955f4ca47c12> in <module>()
#       1 gnb=GaussianNB()
# ----> 2 gnb.fit(train[['x','y','time']], train['place_id'])
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     173         X, y = check_X_y(X, y)
#     174         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 175                                  sample_weight=sample_weight)
#     176
#     177     @staticmethod
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     363         for y_i in unique_y:
#     364             i = classes.searchsorted(y_i)
# --> 365             X_i = X[y == y_i, :]
#     366
#     367             if sample_weight is not None:
#
# KeyboardInterrupt:
