# %%
import os

import time
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm as cm
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.covariance import EllipticEnvelope
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

import pickle

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

# %%
train=pd.read_csv('../input/train.csv')
test=pd.read_csv('../input/test.csv')

places=train['place_id'].unique()
train=train[train['accuracy']>2]
placeCounts=train['place_id'].value_counts()
train=train[(placeCounts[train['place_id']]>10).values]

# %%
def featureFactory(dataFrame):
    dataFrame.loc[:,'day']=dataFrame.loc[:, 'time'].div(1440).map(int)
    dataFrame.loc[:,'weekday']=dataFrame.loc[:,'day']%7
    dataFrame.loc[:,'year']=dataFrame.loc[:,'day'].div(365).map(int)
    dataFrame.loc[:,'month']=(dataFrame.loc[:,'day']%365).div(30).map(int)
    dataFrame.loc[:,'hour']=dataFrame.loc[:,'time'].div(60).map(int)
    dataFrame.loc[:, 'hourInDay']=dataFrame.loc[:,'hour']%24
    
    dataFrame.loc[:, 'originalIndex']=xrange(len(dataFrame))

    
featureFactory(train)
featureFactory(test)

# %%
nXRegions=50
nYRegions=50

xMin=0
xMax=10.1
yMin=0
yMax=10.1
nXRegions=nXRegions*int(xMax-xMin)/10
nYRegions=nYRegions*int(yMax-yMin)/10
train=train[(train['x']<xMax) & (train['x']>=xMin) & (train['y']<yMax) & (train['y']>=yMin)]
f=['x','y','accuracy', 'day', 'weekday', 'hourInDay', 'month', 'year']

# %%
def train_test(modelSerialization=False, resultSerialization=False, model='rf', predictSet=test):
    
    

    if modelSerialization or resultSerialization:
        base='./'
        folderName=model+'-'+time.strftime('%c')
        folderPath=base+folderName+'/'
        if not os.path.exists(folderPath):
            os.makedirs(folderPath)
            
        
    count=0
    accuracies=[]
    FBscores=[]
    
    startTime=time.time()
    trainingTimes=[]
    predictionTimes=[]
    
    testNum=0

    roundNum=5
    for xNum, yNum in ((xn, yn) for xn in xrange(nXRegions) for yn in xrange(nYRegions)):

        xStep=round(1.0*(xMax-xMin)/nXRegions,roundNum)
        xStart=round(xNum*xStep,roundNum)
        xEnd=round(xStart+xStep,roundNum)

        yStep=round(1.0*(yMax-yMin)/nYRegions,roundNum)
        yStart=round(yNum*yStep,roundNum)
        yEnd=round(yStart+yStep,roundNum)

        regionalTrain=train[(train['x']<xEnd) & (train['x']>=xStart) & (train['y']<yEnd) & (train['y']>=yStart)]

        if len(regionalTrain):
            regionalPredictSet=predictSet[(predictSet['x']<xEnd) & (predictSet['x']>=xStart) & (predictSet['y']<yEnd) & (predictSet['y']>=yStart)]
            testNum+=len(regionalPredictSet)
            
            trainingStartTime=time.time()
#             clf=RandomForestClassifier(n_jobs=8, n_estimators=300, max_features=None).fit(regionalTrain[f], regionalTrain['place_id'])   
            clf=RandomForestClassifier(n_jobs=8, n_estimators=100, random_state=0).fit(regionalTrain[f], regionalTrain['place_id'])   
#             clf=XGBClassifier(learning_rate=0.03, n_estimators=50, objective='multi:softprob').fit(regionalTrain[f], regionalTrain['place_id'])

            trainingTimes.append(time.time()-trainingStartTime)
            
            
            if modelSerialization:
                modelFileName='{:04d}-{}-{}-{}-{}.clf'.format(count, xStart, xEnd, yStart, yEnd)
                modelFilePath=folderPath+modelFileName
                with open(modelFilePath, 'ab+') as fo:
                    pickle.dump(clf, fo, pickle.HIGHEST_PROTOCOL)
            
            
            predictionStartTime=time.time()
            prob=clf.predict_proba(regionalPredictSet[f])
            predictionTimes.append(time.time()-predictionStartTime)
            
            pred=[sorted(zip(p, clf.classes_))[-3:][::-1] for p in prob]
            prediction=[zip(*p)[1] for p in pred]
            confidence=[zip(*p)[0] for p in pred]
            
            if resultSerialization:
                resultFileName='{:04d}-{}-{}-{}-{}.rst'.format(count, xStart, xEnd, yStart, yEnd)
                resultFilePath=folderPath+resultFileName
                predColumns=zip(*prediction)
                confColumns=zip(*confidence)

                
                if len(predColumns[2])!=len(prediction):
                    print 'missing values',count, len(predColumns[0])
                
                results=pd.DataFrame({'originalIndex': regionalPredictSet['originalIndex'].tolist(),\
                                      'x':regionalPredictSet['x'].tolist(), 'y':regionalPredictSet['y'].tolist(), \
                                      'accuracy':regionalPredictSet['accuracy'].tolist(), 'pred0':predColumns[0], \
                                      'pred1':predColumns[1], 'pred2':predColumns[2], 'conf0': confColumns[0], \
                                      'conf1': confColumns[1], 'conf2': confColumns[2]})

                results.to_csv(resultFilePath)
                
            if 'place_id' in predictSet.columns:
                regionalAccuracy=1.0*sum([regionalPredictSet['place_id'].iloc[i] in prediction[i] for i in xrange(len(regionalPredictSet))])/len(regionalPredictSet)
                regionalConfidence=[sum(z)/len(regionalPredictSet) for z in zip(*confidence)]
                regionalConfidence3=sum(regionalConfidence)

                fbAccuracy=0
                fbAccuracy+=1.0*sum([regionalPredictSet['place_id'].iloc[i] in prediction[i][:1] for i in xrange(len(regionalPredictSet))])/len(regionalPredictSet)
                fbAccuracy+=1.0/2*sum([regionalPredictSet['place_id'].iloc[i] in prediction[i][1:2] for i in xrange(len(regionalPredictSet))])/len(regionalPredictSet)
                fbAccuracy+=1.0/3*sum([regionalPredictSet['place_id'].iloc[i] in prediction[i][2:3] for i in xrange(len(regionalPredictSet))])/len(regionalPredictSet)
                FBscores.append(fbAccuracy)




                print 'region {}: {},{} accuracy: {},  fbAccu: {}, confidence: {}:'.format(count, xNum, yNum, regionalAccuracy, fbAccuracy, regionalConfidence3)
                accuracies.append(regionalAccuracy)



        count+=1
        if count%10==0:

            print '{} : total time {} s.'.format(count, time.time()-startTime)
            print 'Average training Time: ', sum(trainingTimes)/len(trainingTimes)
            print 'Average prediction Time: ', sum(predictionTimes)/len(predictionTimes)
            print 'Average FB Score', np.mean(FBscores)
            print 
            
            startTime=time.time()
            trainingTimes=[]
            predictionTimes=[]


    print 
    print np.mean(accuracies)
    print np.var(accuracies)
    print
    print np.mean(FBscores)
    print testNum
    print 'done'

# %%
train_test(modelSerialization=False, resultSerialization=True, predictSet=test)
# Out:
# 10 : total time 34.9062731266 s.
# Average training Time:  2.26710412502
# Average prediction Time:  0.55340218544
# Average FB Score nan
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# 20 : total time 31.7451200485 s.
# Average training Time:  1.99052786827
# Average prediction Time:  0.50916864872
# Average FB Score nan
#
# 30 : total time 28.4251279831 s.
# Average training Time:  1.69565799236
# Average prediction Time:  0.504885792732
# Average FB Score nan
#
# 40 : total time 25.8056108952 s.
# Average training Time:  1.57326834202
# Average prediction Time:  0.431703400612
# Average FB Score nan
#
# 50 : total time 29.9931919575 s.
# Average training Time:  1.87205679417
# Average prediction Time:  0.472648262978
# Average FB Score nan
#
# 60 : total time 37.5360429287 s.
# Average training Time:  2.44007055759
# Average prediction Time:  0.581934213638
# Average FB Score nan
#
# 70 : total time 38.8908450603 s.
# Average training Time:  2.59287686348
# Average prediction Time:  0.592994070053
# Average FB Score nan
#
# 80 : total time 35.8970358372 s.
# Average training Time:  2.22943532467
# Average prediction Time:  0.661800122261
# Average FB Score nan
#
# 90 : total time 31.9847149849 s.
# Average training Time:  1.99824147224
# Average prediction Time:  0.558690929413
# Average FB Score nan
#
# 100 : total time 33.7108228207 s.
# Average training Time:  2.18119933605
# Average prediction Time:  0.532319617271
# Average FB Score nan
#
# 110 : total time 40.6863059998 s.
# Average training Time:  2.60416550636
# Average prediction Time:  0.718711566925
# Average FB Score nan
#
# 120 : total time 35.9876420498 s.
# Average training Time:  2.37180480957
# Average prediction Time:  0.568243646622
# Average FB Score nan
#
# 130 : total time 36.7368059158 s.
# Average training Time:  2.42369329929
# Average prediction Time:  0.580325460434
# Average FB Score nan
#
# 140 : total time 33.9531359673 s.
# Average training Time:  2.21776897907
# Average prediction Time:  0.534395170212
# Average FB Score nan
#
# 150 : total time 37.655744791 s.
# Average training Time:  2.40883369446
# Average prediction Time:  0.656076812744
# Average FB Score nan
#
# 160 : total time 39.1575820446 s.
# Average training Time:  2.57297646999
# Average prediction Time:  0.64142229557
# Average FB Score nan
#
# 800 : total time 48.8115360737 s.
# Average training Time:  3.29977703094
# Average prediction Time:  0.751694369316
# Average FB Score nan
#
# 810 : total time 52.9786009789 s.
# Average training Time:  3.61248214245
# Average prediction Time:  0.795516467094
# Average FB Score nan
#
# 820 : total time 51.6091239452 s.
# Average training Time:  3.44797208309
# Average prediction Time:  0.805031895638
# Average FB Score nan
#
# 830 : total time 49.0319180489 s.
# Average training Time:  3.23021383286
# Average prediction Time:  0.788443684578
# Average FB Score nan
#
# 840 : total time 49.1591730118 s.
# Average training Time:  3.17084050179
# Average prediction Time:  0.828397750854
# Average FB Score nan
#
# 850 : total time 47.3696959019 s.
# Average training Time:  3.11439256668
# Average prediction Time:  0.762220525742
# Average FB Score nan
#
# 860 : total time 43.539121151 s.
# Average training Time:  2.81100010872
# Average prediction Time:  0.716464710236
# Average FB Score nan
#
# 870 : total time 51.9778490067 s.
# Average training Time:  3.47458381653
# Average prediction Time:  0.837473392487
# Average FB Score nan
#
# 880 : total time 49.6635901928 s.
# Average training Time:  3.1413574934
# Average prediction Time:  0.900214719772
# Average FB Score nan
#
# 890 : total time 46.0510811806 s.
# Average training Time:  3.00113198757
# Average prediction Time:  0.774851703644
# Average FB Score nan
#
# 900 : total time 51.4106969833 s.
# Average training Time:  3.50701038837
# Average prediction Time:  0.775795888901
# Average FB Score nan
#
# 910 : total time 48.275151968 s.
# Average training Time:  3.19273488522
# Average prediction Time:  0.800720024109
# Average FB Score nan
#
# 920 : total time 51.1211688519 s.
# Average training Time:  3.38253848553
# Average prediction Time:  0.844080781937
# Average FB Score nan
#
# 930 : total time 50.2547090054 s.
# Average training Time:  3.29447488785
# Average prediction Time:  0.834515237808
# Average FB Score nan
#
# 940 : total time 50.1338472366 s.
# Average training Time:  3.35500798225
# Average prediction Time:  0.79584748745
# Average FB Score nan
#
# 950 : total time 49.2536079884 s.
# Average training Time:  3.37015452385
# Average prediction Time:  0.738293433189
# Average FB Score nan
#
# 960 : total time 52.1561310291 s.
# Average training Time:  3.53670489788
# Average prediction Time:  0.806131100655
# Average FB Score nan
#
# 970 : total time 57.2460930347 s.
# Average training Time:  3.84293100834
# Average prediction Time:  0.91047141552
# Average FB Score nan
#
# 980 : total time 55.2199389935 s.
# Average training Time:  3.80299282074
# Average prediction Time:  0.836249613762
# Average FB Score nan
#
# 990 : total time 53.9464359283 s.
# Average training Time:  3.69129443169
# Average prediction Time:  0.786136245728
# Average FB Score nan
#
# 1000 : total time 53.2719249725 s.
# Average training Time:  3.69270670414
# Average prediction Time:  0.765359091759
# Average FB Score nan
#
# 1010 : total time 45.1749460697 s.
# Average training Time:  2.93390145302
# Average prediction Time:  0.745102763176
# Average FB Score nan
#
# 1020 : total time 53.8726971149 s.
# Average training Time:  3.67340972424
# Average prediction Time:  0.789241099358
# Average FB Score nan
#
# 1030 : total time 58.9437918663 s.
# Average training Time:  4.15281381607
# Average prediction Time:  0.811306452751
# Average FB Score nan
#
# 1040 : total time 55.8049418926 s.
# Average training Time:  3.84952559471
# Average prediction Time:  0.819643235207
# Average FB Score nan
#
# 1050 : total time 48.1203010082 s.
# Average training Time:  3.25235211849
# Average prediction Time:  0.758853983879
# Average FB Score nan
#
# 1060 : total time 55.3811490536 s.
# Average training Time:  3.72798955441
# Average prediction Time:  0.846499013901
# Average FB Score nan
#
# 1070 : total time 52.8739349842 s.
# Average training Time:  3.58985311985
# Average prediction Time:  0.826189112663
# Average FB Score nan
#
# 1080 : total time 51.4306237698 s.
# Average training Time:  3.47164685726
# Average prediction Time:  0.795089387894
# Average FB Score nan
#
# 1090 : total time 57.583313942 s.
# Average training Time:  4.05096514225
# Average prediction Time:  0.798349618912
# Average FB Score nan
#
# 1100 : total time 51.8766229153 s.
# Average training Time:  3.58404662609
# Average prediction Time:  0.767638731003
# Average FB Score nan
#
# 1110 : total time 52.9162909985 s.
# Average training Time:  3.64862658978
# Average prediction Time:  0.79608528614
# Average FB Score nan
#
# 1120 : total time 50.7822680473 s.
# Average training Time:  3.46697719097
# Average prediction Time:  0.781986498833
# Average FB Score nan
#
# 1130 : total time 60.417869091 s.
# Average training Time:  4.25083167553
# Average prediction Time:  0.840196418762
# Average FB Score nan
#
# 1140 : total time 55.8308150768 s.
# Average training Time:  3.89774270058
# Average prediction Time:  0.794810032845
# Average FB Score nan
#
# 1150 : total time 60.1158189774 s.
# Average training Time:  4.20982680321
# Average prediction Time:  0.825863957405
# Average FB Score nan
#
# 1160 : total time 52.8797779083 s.
# Average training Time:  3.60984716415
# Average prediction Time:  0.821485090256
# Average FB Score nan
#
# 1170 : total time 54.3122279644 s.
# Average training Time:  3.64753136635
# Average prediction Time:  0.868084263802
# Average FB Score nan
#
# 1180 : total time 53.3869748116 s.
# Average training Time:  3.73081688881
# Average prediction Time:  0.745362925529
# Average FB Score nan
#
# 1190 : total time 50.6899371147 s.
# Average training Time:  3.54794592857
# Average prediction Time:  0.724236297607
# Average FB Score nan
#
# 1200 : total time 65.5523440838 s.
# Average training Time:  4.76374251842
# Average prediction Time:  0.816045022011
# Average FB Score nan
#
# 1210 : total time 55.5511579514 s.
# Average training Time:  3.86493120193
# Average prediction Time:  0.807302117348
# Average FB Score nan
#
# 1220 : total time 55.2199029922 s.
# Average training Time:  3.81220653057
# Average prediction Time:  0.834300971031
# Average FB Score nan
#
# 1230 : total time 60.1091639996 s.
# Average training Time:  4.24000837803
# Average prediction Time:  0.831686306
# Average FB Score nan
#
# 1240 : total time 59.761729002 s.
# Average training Time:  4.28969621658
# Average prediction Time:  0.795379447937
# Average FB Score nan
#
# 1250 : total time 57.6460649967 s.
# Average training Time:  4.02871470451
# Average prediction Time:  0.82305059433
# Average FB Score nan
#
# 1260 : total time 65.9723000526 s.
# Average training Time:  4.73049087524
# Average prediction Time:  0.882466173172
# Average FB Score nan
#
# 1270 : total time 57.7283649445 s.
# Average training Time:  4.01487476826
# Average prediction Time:  0.833867096901
# Average FB Score nan
#
# 1280 : total time 69.7759561539 s.
# Average training Time:  5.02066009045
# Average prediction Time:  0.908629560471
# Average FB Score nan
#
# 1290 : total time 63.9821259975 s.
# Average training Time:  4.55135600567
# Average prediction Time:  0.912593340874
# Average FB Score nan
#
# 1300 : total time 53.2809858322 s.
# Average training Time:  3.78905630112
# Average prediction Time:  0.726408672333
# Average FB Score nan
#
# 1310 : total time 62.9247949123 s.
# Average training Time:  4.48252019882
# Average prediction Time:  0.889330482483
# Average FB Score nan
#
# 1320 : total time 62.3490109444 s.
# Average training Time:  4.43958611488
# Average prediction Time:  0.853309512138
# Average FB Score nan
#
# 1330 : total time 63.3675091267 s.
# Average training Time:  4.54597773552
# Average prediction Time:  0.821464633942
# Average FB Score nan
#
# 1340 : total time 57.5065429211 s.
# Average training Time:  4.11683101654
# Average prediction Time:  0.776444768906
# Average FB Score nan
#
# 1350 : total time 56.1796717644 s.
# Average training Time:  4.05378243923
# Average prediction Time:  0.706170129776
# Average FB Score nan
#
# 1360 : total time 60.5919001102 s.
# Average training Time:  4.19470143318
# Average prediction Time:  0.916844725609
# Average FB Score nan
#
# 1370 : total time 54.7725119591 s.
# Average training Time:  3.86685318947
# Average prediction Time:  0.766778683662
# Average FB Score nan
#
# 1380 : total time 67.8487839699 s.
# Average training Time:  4.95658819675
# Average prediction Time:  0.856666827202
# Average FB Score nan
#
# 1390 : total time 53.9049398899 s.
# Average training Time:  3.7638928175
# Average prediction Time:  0.760841178894
# Average FB Score nan
#
# 1400 : total time 46.1206669807 s.
# Average training Time:  3.08235619068
# Average prediction Time:  0.733779716492
# Average FB Score nan
#
# 1410 : total time 54.6211309433 s.
# Average training Time:  3.76849069595
# Average prediction Time:  0.796459293365
# Average FB Score nan
#
# 1420 : total time 52.4239749908 s.
# Average training Time:  3.61268208027
# Average prediction Time:  0.794382309914
# Average FB Score nan
#
# 1900 : total time 53.7000381947 s.
# Average training Time:  3.86686153412
# Average prediction Time:  0.746444368362
# Average FB Score nan
#
# 1910 : total time 60.9567070007 s.
# Average training Time:  4.51001663208
# Average prediction Time:  0.76228017807
# Average FB Score nan
#
# 1920 : total time 53.4242379665 s.
# Average training Time:  3.87728776932
# Average prediction Time:  0.689175224304
# Average FB Score nan
#
# 1930 : total time 63.9006171227 s.
# Average training Time:  4.67199759483
# Average prediction Time:  0.807382392883
# Average FB Score nan
#
# 1940 : total time 63.9268400669 s.
# Average training Time:  4.68528647423
# Average prediction Time:  0.817778396606
# Average FB Score nan
#
# 1950 : total time 49.1977009773 s.
# Average training Time:  3.55220961571
# Average prediction Time:  0.642967009544
# Average FB Score nan
#
# 1960 : total time 57.0492229462 s.
# Average training Time:  4.1159689188
# Average prediction Time:  0.748742294312
# Average FB Score nan
#
# 1970 : total time 60.4444551468 s.
# Average training Time:  4.48291194439
# Average prediction Time:  0.74573097229
# Average FB Score nan
#
# 1980 : total time 57.4566569328 s.
# Average training Time:  4.17455546856
# Average prediction Time:  0.751733899117
# Average FB Score nan
#
# 1990 : total time 67.3626048565 s.
# Average training Time:  5.0848136425
# Average prediction Time:  0.809256744385
# Average FB Score nan
#
# 2000 : total time 49.1681468487 s.
# Average training Time:  3.57320139408
# Average prediction Time:  0.641274499893
# Average FB Score nan
#
# 2010 : total time 47.2608559132 s.
# Average training Time:  3.36154711246
# Average prediction Time:  0.651417541504
# Average FB Score nan
#
# 2020 : total time 52.9340858459 s.
# Average training Time:  3.86182453632
# Average prediction Time:  0.678213143349
# Average FB Score nan
#
# 2030 : total time 55.4878070354 s.
# Average training Time:  3.99824154377
# Average prediction Time:  0.736945056915
# Average FB Score nan
#
# 2040 : total time 66.34679389 s.
# Average training Time:  4.95823223591
# Average prediction Time:  0.826168298721
# Average FB Score nan
#
# 2050 : total time 57.2635419369 s.
# Average training Time:  4.17371265888
# Average prediction Time:  0.767163300514
# Average FB Score nan
#
# 2060 : total time 55.2288589478 s.
# Average training Time:  4.01160042286
# Average prediction Time:  0.726709079742
# Average FB Score nan
#
# 2070 : total time 44.4197640419 s.
# Average training Time:  3.04651958942
# Average prediction Time:  0.681694936752
# Average FB Score nan
#
# 2080 : total time 52.3131930828 s.
# Average training Time:  3.76882748604
# Average prediction Time:  0.709948825836
# Average FB Score nan
#
# 2090 : total time 56.6752409935 s.
# Average training Time:  4.13010613918
# Average prediction Time:  0.73334941864
# Average FB Score nan
#
# 2100 : total time 52.1180889606 s.
# Average training Time:  3.8194848299
# Average prediction Time:  0.669203782082
# Average FB Score nan
#
# 2110 : total time 49.7595779896 s.
# Average training Time:  3.54706742764
# Average prediction Time:  0.681804490089
# Average FB Score nan
#
# 2120 : total time 48.7678761482 s.
# Average training Time:  3.38339006901
# Average prediction Time:  0.716254067421
# Average FB Score nan
#
# 2130 : total time 59.7877318859 s.
# Average training Time:  4.32037789822
# Average prediction Time:  0.787418889999
# Average FB Score nan
#
# 2140 : total time 54.4360589981 s.
# Average training Time:  3.98556370735
# Average prediction Time:  0.70895485878
# Average FB Score nan
#
# 2150 : total time 55.9408628941 s.
# Average training Time:  4.16345963478
# Average prediction Time:  0.668910050392
# Average FB Score nan
#
# 2160 : total time 51.9466001987 s.
# Average training Time:  3.7399091959
# Average prediction Time:  0.696812343597
# Average FB Score nan
#
# 2170 : total time 51.9077100754 s.
# Average training Time:  3.70945160389
# Average prediction Time:  0.71169989109
# Average FB Score nan
#
# 2180 : total time 57.1743569374 s.
# Average training Time:  4.139260149
# Average prediction Time:  0.765971517563
# Average FB Score nan
#
# 2190 : total time 54.8999710083 s.
# Average training Time:  3.98308777809
# Average prediction Time:  0.712017393112
# Average FB Score nan
#
# 2200 : total time 52.6692721844 s.
# Average training Time:  3.84056704044
# Average prediction Time:  0.689712285995
# Average FB Score nan
#
# 2210 : total time 50.6539168358 s.
# Average training Time:  3.61679699421
# Average prediction Time:  0.750377964973
# Average FB Score nan
#
# 2220 : total time 47.5812251568 s.
# Average training Time:  3.42160210609
# Average prediction Time:  0.62914056778
# Average FB Score nan
#
# 2230 : total time 47.3857460022 s.
# Average training Time:  3.30662095547
# Average prediction Time:  0.685697484016
# Average FB Score nan
#
# 2240 : total time 53.4898250103 s.
# Average training Time:  3.93538403511
# Average prediction Time:  0.678625941277
# Average FB Score nan
#
# 2250 : total time 51.6482429504 s.
# Average training Time:  3.72718741894
# Average prediction Time:  0.692808532715
# Average FB Score nan
#
# 2260 : total time 52.3280031681 s.
# Average training Time:  3.86477437019
# Average prediction Time:  0.656234288216
# Average FB Score nan
#
# 2270 : total time 46.5313589573 s.
# Average training Time:  3.21668717861
# Average prediction Time:  0.714036178589
# Average FB Score nan
#
# 2280 : total time 48.7254021168 s.
# Average training Time:  3.52474710941
# Average prediction Time:  0.649741101265
# Average FB Score nan
#
# 2290 : total time 44.7123410702 s.
# Average training Time:  3.15999410152
# Average prediction Time:  0.610131907463
# Average FB Score nan
#
# 2300 : total time 44.5283200741 s.
# Average training Time:  3.20643281937
# Average prediction Time:  0.589665174484
# Average FB Score nan
#
# 2310 : total time 48.3329319954 s.
# Average training Time:  3.44018039703
# Average prediction Time:  0.690408706665
# Average FB Score nan
#
# 2320 : total time 40.5992629528 s.
# Average training Time:  2.91044306755
# Average prediction Time:  0.539787197113
# Average FB Score nan
#
# 2330 : total time 44.6357820034 s.
# Average training Time:  3.0964152813
# Average prediction Time:  0.662290859222
# Average FB Score nan
#
# 2340 : total time 49.9400091171 s.
# Average training Time:  3.7077892065
# Average prediction Time:  0.582942986488
# Average FB Score nan
#
# 2350 : total time 46.0038211346 s.
# Average training Time:  3.26495087147
# Average prediction Time:  0.647732400894
# Average FB Score nan
#
# 2360 : total time 43.6263871193 s.
# Average training Time:  3.03393604755
# Average prediction Time:  0.632534170151
# Average FB Score nan
#
# 2370 : total time 41.8943021297 s.
# Average training Time:  2.93747997284
# Average prediction Time:  0.608504676819
# Average FB Score nan
#
# 2380 : total time 40.767580986 s.
# Average training Time:  2.77054522038
# Average prediction Time:  0.624634361267
# Average FB Score nan
#
# 2390 : total time 43.8215100765 s.
# Average training Time:  3.14690816402
# Average prediction Time:  0.598734378815
# Average FB Score nan
#
# 2400 : total time 38.6184110641 s.
# Average training Time:  2.65267059803
# Average prediction Time:  0.576010274887
# Average FB Score nan
#
# 2410 : total time 46.8520569801 s.
# Average training Time:  3.45604047775
# Average prediction Time:  0.557428693771
# Average FB Score nan
#
# 2420 : total time 43.9295129776 s.
# Average training Time:  3.14790480137
# Average prediction Time:  0.572067904472
# Average FB Score nan
#
# 2430 : total time 46.2362310886 s.
# Average training Time:  3.301435256
# Average prediction Time:  0.582260799408
# Average FB Score nan
#
# 2440 : total time 39.7878301144 s.
# Average training Time:  2.75971419811
# Average prediction Time:  0.580200529099
# Average FB Score nan
#
# 2450 : total time 36.1041200161 s.
# Average training Time:  2.37253792286
# Average prediction Time:  0.611925196648
# Average FB Score nan
#
# 2460 : total time 13.7709200382 s.
# Average training Time:  0.821361207962
# Average prediction Time:  0.267225980759
# Average FB Score nan
#
# 2470 : total time 13.3903689384 s.
# Average training Time:  0.804707598686
# Average prediction Time:  0.244327878952
# Average FB Score nan
#
# 2480 : total time 12.5556528568 s.
# Average training Time:  0.73104789257
# Average prediction Time:  0.236899375916
# Average FB Score nan
#
# 2490 : total time 13.9253280163 s.
# Average training Time:  0.825038337708
# Average prediction Time:  0.256520485878
# Average FB Score nan
#
# 2500 : total time 13.716452837 s.
# Average training Time:  0.853049778938
# Average prediction Time:  0.222086143494
# Average FB Score nan
#
#
# nan
# nan
#
# nan
# 8607230
# done
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)

# %%
def makeSubmission(resultFolder):
    results=[]
    for f in os.listdir(resultFolder):
        if f.endswith('.rst'):
            fi=resultFolder+'/'+f
            results.append(pd.read_csv(fi))
    results=pd.concat(results)
        
    results.sort(['originalIndex'], inplace=True)
    return results

# %%
results=makeSubmission('../submissions/rf100Trees50-50Fulltraining/')
predictions=results[['pred0','pred1','pred2']]
submit=pd.DataFrame()
# submit.loc[:,'row_id']=np.arange(len(predictions))
submit.loc[:,'place_id']=predictions[['pred0', 'pred1', 'pred2']].apply(lambda x: ' '.join([str(nx) for nx in x]), axis=1)
submit.loc[:,'row_id']=np.arange(len(predictions))
# Out:
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
submit=submit[['row_id','place_id' ]]
submit.set_index('row_id', inplace=True)
submit.to_csv('../submissions/rf100Trees50-50Fulltraining.csv')
