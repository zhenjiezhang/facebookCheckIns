# %%
'''Partially based on several scripts:
https://www.kaggle.com/c/facebook-v-predicting-check-ins/scripts
'''

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

#print('	Reading train.csv')
df_train = pd.read_csv('../input/train.csv',
                        usecols=['row_id','x','y','time','place_id','accuracy'], 
                        index_col = 0)
#print('	Reading test.csv')
df_test = pd.read_csv('../input/test.csv',
                        usecols=['row_id','x','y','time','accuracy'],
                        index_col = 0)

print('Feature Augmentation')
minute = df_train.time%60
df_train['hour'] = df_train['time'].div(60).map(int)
df_train.drop(['time'], axis=1, inplace=True)
df_train['weekday'] = df_train['hour'].div(24).map(int)
df_train['month'] = df_train['weekday'].div(30).map(int)
df_train['year'] = (df_train['weekday'].div(365).map(int)+1)*10.0
df_train['hour'] = ((df_train.loc[:,'hour'].values%(24)+1)+minute.div(60.0))*(4.0)


df_train['weekday'] = (df_train['weekday']%7+1)*3.0
df_train['month'] = (df_train['month']%12+1)*2.0
df_train['accuracy'] = np.log10(df_train['accuracy'])*10.0

print ('training processing is done')

minute = df_test['time']%60
df_test['hour'] = df_test['time'].div(60).map(int)
df_test.drop(['time'], axis=1, inplace=True)
df_test['weekday'] = df_test['hour'].div(24).map(int)
df_test['month'] = df_test['weekday'].div(30).map(int)
df_test['year'] = (df_test['weekday'].div(365).map(int)+1)*10.0
df_test['hour'] = ((df_test['hour']%24+1)+minute.div(60.0)).mul(4.0)
df_test['weekday'] = (df_test['weekday']%7+1)*3.0
df_test['month'] = (df_test['month']%12+1)*2.0
df_test['accuracy'] = np.log10(df_test['accuracy'])*10.0
print ('test processing is done')
                   
# add data for periodic time that hit the boundary
add_data = df_train[df_train.hour<6]
add_data.hour = add_data.hour+96
df_train = df_train.append(add_data)

add_data = df_train[df_train.hour>98]
add_data.hour = add_data.hour-96
df_train = df_train.append(add_data)


pd.options.mode.chained_assignment = None

def calculate_distance(distances):
    return distances ** -2

def process_one_cell(df_cell_train, df_cell_test):
    
    #Working on df_train
    place_counts = df_cell_train.place_id.value_counts()
    mask = (place_counts[df_cell_train.place_id.values] >= 8).values
    df_cell_train = df_cell_train.loc[mask]
    
    #Working on df_test
    row_ids = df_cell_test.index
    
    #Feature engineering on x and y
    df_cell_train.loc[:,'x'] *= 500.0
    df_cell_train.loc[:,'y'] *= 1000.0
    df_cell_test.loc[:,'x'] *= 500.0
    df_cell_test.loc[:,'y'] *= 1000.0
    
    #Preparing data
    le = LabelEncoder()
    y = le.fit_transform(df_cell_train.place_id.values)
    X = df_cell_train.drop(['place_id'], axis=1).values
    X_test = df_cell_test.values

    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=36, weights=calculate_distance, metric='manhattan', n_jobs=-1)
    clf.fit(X, y)
    y_pred = clf.predict_proba(X_test)
    pred_labels = le.inverse_transform(np.argsort(y_pred, axis=1)[:,::-1][:,:3]) 
    
    return pred_labels, row_ids
   
def process_grid(df_train, df_test):
    """
    Iterates over all grid cells, aggregates the results
    """
    size = 10.0
    x_step = 0.5
    y_step = 0.25
    
    x_border_augment = 0.1    
    y_border_augment = 0.05
    
    preds = np.zeros((df_test.shape[0], 3), dtype=int)

    for i in range((int)(size/x_step)):
        
        x_min = x_step * i
        x_max = x_step * (i+1)
        x_min = round(x_min, 4)
        x_max = round(x_max, 4) 
        if x_max == size:
            x_max = x_max + 0.001
            
        df_col_train = df_train[(df_train['x'] >= x_min-x_border_augment) & (df_train['x'] < x_max+x_border_augment)]
        df_col_test = df_test[(df_test['x'] >= x_min) & (df_test['x'] < x_max)]

        for j in range((int)(size/y_step)):
            y_min = y_step * j
            y_max = y_step * (j+1)
            y_min = round(y_min, 4)
            y_max = round(y_max, 4)   
            if y_max == size:
                y_max = y_max + 0.001
                
            df_cell_train = df_col_train[(df_col_train['y'] >= y_min-y_border_augment) & (df_col_train['y'] < y_max+y_border_augment)]
            df_cell_test = df_col_test[(df_col_test['y'] >= y_min) & (df_col_test['y'] < y_max)]
            
            #Applying classifier to one grid cell
            pred_labels, row_ids = process_one_cell(df_cell_train, df_cell_test)

            #Updating predictions
            preds[row_ids] = pred_labels
        print i, ' columns are done'
            
    #Auxiliary dataframe with the 3 best predictions for each sample
    df_aux = pd.DataFrame(preds, dtype=str, columns=['l1', 'l2', 'l3'])
    
    print 'procesing is done'
    return df_aux

def generate_sub(df_aux):    
    #print('Writing submission file')
    #Concatenating the 3 predictions for each sample
    ds_sub = df_aux.l1.str.cat([df_aux.l2, df_aux.l3], sep=' ')
    
    #Writting to csv
    ds_sub.name = 'place_id'
    ds_sub.to_csv('submission_sample.csv', index=True, header=True, index_label='row_id')

df_aux=process_grid(df_train, df_test)

generate_sub(df_aux)
print 'file generated'
# Out:
# Feature Augmentation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cfc5db5ef493> in <module>()
#      20 minute = df_train.time%60
#      21 df_train['hour'] = df_train['time'].div(60).map(int)
# ---> 22 df_train.drop(['time'], axis=1, inplace=True)
#      23 df_train['weekday'] = df_train['hour'].div(24).map(int)
#      24 df_train['month'] = df_train['weekday'].div(30).map(int)
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1872             else:
#    1873                 new_axis = axis.drop(labels, errors=errors)
# -> 1874             dropped = self.reindex(**{axis_name: new_axis})
#    1875             try:
#    1876                 dropped.axes[axis_].set_names(axis.names, inplace=True)
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in reindex(self, index, columns, **kwargs)
#    2733     def reindex(self, index=None, columns=None, **kwargs):
#    2734         return super(DataFrame, self).reindex(index=index, columns=columns,
# -> 2735                                               **kwargs)
#    2736
#    2737     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in reindex(self, *args, **kwargs)
#    2205                             'argument "{0}"'.format(list(kwargs.keys())[0]))
#    2206
# -> 2207         self._consolidate_inplace()
#    2208
#    2209         # if all axes that are requested to reindex are equal, then only copy
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _consolidate_inplace(self)
#    2724             self._data = self._data.consolidate()
#    2725
# -> 2726         self._protect_consolidate(f)
#    2727
#    2728     def consolidate(self, inplace=False):
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _protect_consolidate(self, f)
#    2713         """
#    2714         blocks_before = len(self._data.blocks)
# -> 2715         result = f()
#    2716         if len(self._data.blocks) != blocks_before:
#    2717             self._clear_item_cache()
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in f()
#    2722
#    2723         def f():
# -> 2724             self._data = self._data.consolidate()
#    2725
#    2726         self._protect_consolidate(f)
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in consolidate(self)
#    3206         bm = self.__class__(self.blocks, self.axes)
#    3207         bm._is_consolidated = False
# -> 3208         bm._consolidate_inplace()
#    3209         return bm
#    3210
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate_inplace(self)
#    3211     def _consolidate_inplace(self):
#    3212         if not self.is_consolidated():
# -> 3213             self.blocks = tuple(_consolidate(self.blocks))
#    3214             self._is_consolidated = True
#    3215             self._known_consolidated = True
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate(blocks)
#    4196     for (_can_consolidate, dtype), group_blocks in grouper:
#    4197         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4198                                       _can_consolidate=_can_consolidate)
#    4199         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4200     return new_blocks
#
# /home/zhenjie/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in _merge_blocks(blocks, dtype, _can_consolidate)
#    4219
#    4220         argsort = np.argsort(new_mgr_locs)
# -> 4221         new_values = new_values[argsort]
#    4222         new_mgr_locs = new_mgr_locs[argsort]
#    4223
#
# KeyboardInterrupt:
