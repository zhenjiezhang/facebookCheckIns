# %%
import pandas as pd

# %%
train=pd.read_csv('train.csv', nrows=10);
test=pd.read_csv('test.csv', nrows=10);
samples=pd.read_csv('sample_submission.csv', nrows=10);

# %%
train.head()
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713
# 2       2  8.3078  7.0407        74  322648  1137537235
# 3       3  7.3665  2.5165        65  704587  6567393236
# 4       4  4.0961  1.1307        31  472130  7440663949

# %%
test.head()
# Out:
#    row_id       x       y  accuracy    time
# 0       0  0.1675  1.3608       107  930883
# 1       1  7.3909  2.5301        35  893017
# 2       2  8.0978  2.3473        62  976933
# 3       3  0.9990  1.0591        62  907285
# 4       4  0.6670  9.7254        40  914399

# %%
samples.head()
# Out:
#    row_id                          place_id
# 0       0  3073560757 9004412889 5652080691
# 1       1  1652178628 4379515211 6612350960
# 2       2  4894407065 3920195083 7608574746
# 3       3  7272466660 2004687925 1455486822
# 4       4  4720452725 4967325204 4782917866

# %%
train=pd.read_csv('train.csv');
test=pd.read_csv('test.csv');
samples=pd.read_csv('sample_submission.csv');

# %%
print train.x.max(), train.x.min(), train.y.max(), train.y.min()
# Out:
# 10.0 0.0 10.0 0.0

# %%
groups=train.place_id.value_counts()

# %%
groups.head()
type(groups)
# Out:
# pandas.core.series.Series

# %%
groupby=train.groupby('place_id')
groupby.head()
# Out:
#             row_id       x       y  accuracy    time    place_id
# 0                0  0.7941  9.0809        54  470702  8523065625
# 1                1  5.9567  4.7968        13  186555  1757726713
# 2                2  8.3078  7.0407        74  322648  1137537235
# 3                3  7.3665  2.5165        65  704587  6567393236
# 4                4  4.0961  1.1307        31  472130  7440663949
# 5                5  3.8099  1.9586        75  178065  6289802927
# 6                6  6.3336  4.3720        13  666829  9931249544
# 7                7  5.7409  6.7697        85  369002  5662813655
# 8                8  4.3114  6.9410         3  166384  8471780938
# 9                9  6.3414  0.0758        65  400060  1253803156
# 10              10  2.0173  4.8627         6   21353  8684462954
# 11              11  8.7101  2.9442        73  153493  2159916487
# 12              12  0.8829  1.3445        64  574488  7652380351
# ...

# %%
train.x.describe()
# Out:
# count    2.911802e+07
# mean     4.999770e+00
# std      2.857601e+00
# min      0.000000e+00
# 25%      2.534700e+00
# 50%      5.009100e+00
# 75%      7.461400e+00
# max      1.000000e+01
# Name: x, dtype: float64

# %%
type(groupby)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
frequentPlaces=groupby.count().sort_values('time', ascending=False)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
a=3
b=4
a
b
# Out:
# 3
# 4

# %%
a
b
# Out:
# 3
# 4
